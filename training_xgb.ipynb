# %% [markdown]
# ## Training (XGBoost edition)
# After loading and preprocessing the data, we can now train the model.
#
# ### First things first
# Importing libraries. Make sure you have them installed (check the instructions in the `README.md`)
#
# Then, let's find the best hyperparams using GridSearch

# %%
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

from sklearn.model_selection import GridSearchCV

# Load the processed data
df = pd.read_csv('data/' + 'train_processed.csv')

# Split features and labels
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8, 1],
    'colsample_bytree': [0.7, 0.8, 1],
    'min_child_weight':[1, 5, 10],      
    'gamma':           [0, 1, 5]        
}

grid = GridSearchCV(xgb.XGBClassifier(objective='binary:logistic', random_state=42),
                    param_grid,
                    scoring='roc_auc',
                    cv=3,
                    verbose=1,
                    n_jobs=-1)

grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 2187 candidates, totalling 6561 fits
# Best params: {'colsample_bytree': 0.8, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'n_estimators': 300, 'subsample': 0.7}

# %% [markdown]
# ### On to training!
# Now that we have the best hyperparameters, let's train the classifier.

# %%
# defaults: learning_rate=0.1, n_estimators=100, max_depth=6
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=grid.best_params_['n_estimators'],
    learning_rate=grid.best_params_['learning_rate'],
    max_depth=grid.best_params_['max_depth'],
    subsample=grid.best_params_['subsample'],
    colsample_bytree=grid.best_params_['colsample_bytree'],
    gamma=grid.best_params_['gamma'],
    min_child_weight=grid.best_params_['min_child_weight'],
    random_state=67
)

model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print('Accuracy:', accuracy_score(y_test, y_pred))
print('ROC AUC:', roc_auc_score(y_test, y_proba))
# Out:
# [0]	validation_0-auc:0.85908
# [1]	validation_0-auc:0.87181
# [2]	validation_0-auc:0.87931
# [3]	validation_0-auc:0.88577
# [4]	validation_0-auc:0.88860
# [5]	validation_0-auc:0.88896
# [6]	validation_0-auc:0.89013
# [7]	validation_0-auc:0.88910
# [8]	validation_0-auc:0.89223
# [9]	validation_0-auc:0.89217
# [10]	validation_0-auc:0.89262
# [11]	validation_0-auc:0.89275
# [12]	validation_0-auc:0.89488
# [13]	validation_0-auc:0.89631
# [14]	validation_0-auc:0.89666
# [15]	validation_0-auc:0.89627
# [16]	validation_0-auc:0.89681
# [17]	validation_0-auc:0.89608
# [18]	validation_0-auc:0.89689
# [19]	validation_0-auc:0.89736
# [20]	validation_0-auc:0.89711
# [21]	validation_0-auc:0.89745
# [22]	validation_0-auc:0.89889
# [23]	validation_0-auc:0.89901
# [24]	validation_0-auc:0.89895
# [25]	validation_0-auc:0.90082
# [26]	validation_0-auc:0.90133
# [27]	validation_0-auc:0.90163
# [28]	validation_0-auc:0.90251
# [29]	validation_0-auc:0.90276
# [30]	validation_0-auc:0.90293
# [31]	validation_0-auc:0.90309
# [32]	validation_0-auc:0.90323
# [33]	validation_0-auc:0.90361
# [34]	validation_0-auc:0.90368
# [35]	validation_0-auc:0.90452
# [36]	validation_0-auc:0.90483
# [37]	validation_0-auc:0.90483
# [38]	validation_0-auc:0.90478
# [39]	validation_0-auc:0.90497
# [40]	validation_0-auc:0.90532
# [41]	validation_0-auc:0.90526
# [42]	validation_0-auc:0.90597
# [43]	validation_0-auc:0.90630
# [44]	validation_0-auc:0.90644
# [45]	validation_0-auc:0.90643
# [46]	validation_0-auc:0.90676
# [47]	validation_0-auc:0.90669
# [48]	validation_0-auc:0.90674
# [49]	validation_0-auc:0.90689
# [50]	validation_0-auc:0.90692
# [51]	validation_0-auc:0.90692
# [52]	validation_0-auc:0.90704
# [53]	validation_0-auc:0.90689
# [54]	validation_0-auc:0.90693
# [55]	validation_0-auc:0.90718
# [56]	validation_0-auc:0.90718
# [57]	validation_0-auc:0.90705
# [58]	validation_0-auc:0.90684
# [59]	validation_0-auc:0.90686
# [60]	validation_0-auc:0.90675
# [61]	validation_0-auc:0.90675
# [62]	validation_0-auc:0.90726
# [63]	validation_0-auc:0.90726
# [64]	validation_0-auc:0.90725
# [65]	validation_0-auc:0.90725
# [66]	validation_0-auc:0.90725
# [67]	validation_0-auc:0.90726
# [68]	validation_0-auc:0.90726
# [69]	validation_0-auc:0.90726
# [70]	validation_0-auc:0.90726
# [71]	validation_0-auc:0.90726
# [72]	validation_0-auc:0.90728
# [73]	validation_0-auc:0.90735
# [74]	validation_0-auc:0.90735
# [75]	validation_0-auc:0.90735
# [76]	validation_0-auc:0.90735
# [77]	validation_0-auc:0.90735
# [78]	validation_0-auc:0.90735
# [79]	validation_0-auc:0.90735
# [80]	validation_0-auc:0.90735
# [81]	validation_0-auc:0.90735
# [82]	validation_0-auc:0.90735
# [83]	validation_0-auc:0.90735
# [84]	validation_0-auc:0.90735
# [85]	validation_0-auc:0.90735
# [86]	validation_0-auc:0.90735
# [87]	validation_0-auc:0.90735
# [88]	validation_0-auc:0.90730
# [89]	validation_0-auc:0.90730
# [90]	validation_0-auc:0.90722
# [91]	validation_0-auc:0.90736
# [92]	validation_0-auc:0.90736
# [93]	validation_0-auc:0.90736
# [94]	validation_0-auc:0.90734
# [95]	validation_0-auc:0.90734
# [96]	validation_0-auc:0.90734
# [97]	validation_0-auc:0.90734
# [98]	validation_0-auc:0.90734
# [99]	validation_0-auc:0.90787
# [100]	validation_0-auc:0.90788
# [101]	validation_0-auc:0.90788
# [102]	validation_0-auc:0.90788
# [103]	validation_0-auc:0.90788
# [104]	validation_0-auc:0.90788
# [105]	validation_0-auc:0.90790
# [106]	validation_0-auc:0.90787
# [107]	validation_0-auc:0.90787
# [108]	validation_0-auc:0.90787
# [109]	validation_0-auc:0.90787
# [110]	validation_0-auc:0.90776
# [111]	validation_0-auc:0.90776
# [112]	validation_0-auc:0.90776
# [113]	validation_0-auc:0.90776
# [114]	validation_0-auc:0.90776
# [115]	validation_0-auc:0.90776
# [116]	validation_0-auc:0.90776
# [117]	validation_0-auc:0.90776
# [118]	validation_0-auc:0.90776
# [119]	validation_0-auc:0.90776
# [120]	validation_0-auc:0.90776
# [121]	validation_0-auc:0.90776
# [122]	validation_0-auc:0.90776
# [123]	validation_0-auc:0.90776
# [124]	validation_0-auc:0.90776
# [125]	validation_0-auc:0.90776
# [126]	validation_0-auc:0.90776
# [127]	validation_0-auc:0.90776
# [128]	validation_0-auc:0.90776
# [129]	validation_0-auc:0.90776
# [130]	validation_0-auc:0.90776
# [131]	validation_0-auc:0.90769
# [132]	validation_0-auc:0.90769
# [133]	validation_0-auc:0.90769
# [134]	validation_0-auc:0.90793
# [135]	validation_0-auc:0.90793
# [136]	validation_0-auc:0.90793
# [137]	validation_0-auc:0.90793
# [138]	validation_0-auc:0.90793
# [139]	validation_0-auc:0.90793
# [140]	validation_0-auc:0.90793
# [141]	validation_0-auc:0.90793
# [142]	validation_0-auc:0.90793
# [143]	validation_0-auc:0.90793
# [144]	validation_0-auc:0.90793
# [145]	validation_0-auc:0.90793
# [146]	validation_0-auc:0.90793
# [147]	validation_0-auc:0.90793
# [148]	validation_0-auc:0.90793
# [149]	validation_0-auc:0.90793
# [150]	validation_0-auc:0.90793
# [151]	validation_0-auc:0.90793
# [152]	validation_0-auc:0.90793
# [153]	validation_0-auc:0.90793
# [154]	validation_0-auc:0.90793
# [155]	validation_0-auc:0.90793
# [156]	validation_0-auc:0.90793
# [157]	validation_0-auc:0.90793
# [158]	validation_0-auc:0.90798
# [159]	validation_0-auc:0.90798
# [160]	validation_0-auc:0.90803
# [161]	validation_0-auc:0.90834
# [162]	validation_0-auc:0.90834
# [163]	validation_0-auc:0.90834
# [164]	validation_0-auc:0.90834
# [165]	validation_0-auc:0.90834
# [166]	validation_0-auc:0.90834
# [167]	validation_0-auc:0.90834
# [168]	validation_0-auc:0.90840
# [169]	validation_0-auc:0.90840
# [170]	validation_0-auc:0.90840
# [171]	validation_0-auc:0.90840
# [172]	validation_0-auc:0.90840
# [173]	validation_0-auc:0.90840
# [174]	validation_0-auc:0.90843
# [175]	validation_0-auc:0.90881
# [176]	validation_0-auc:0.90886
# [177]	validation_0-auc:0.90886
# [178]	validation_0-auc:0.90886
# [179]	validation_0-auc:0.90886
# [180]	validation_0-auc:0.90886
# [181]	validation_0-auc:0.90886
# [182]	validation_0-auc:0.90886
# [183]	validation_0-auc:0.90886
# [184]	validation_0-auc:0.90913
# [185]	validation_0-auc:0.90913
# [186]	validation_0-auc:0.90913
# [187]	validation_0-auc:0.90913
# [188]	validation_0-auc:0.90913
# [189]	validation_0-auc:0.90926
# [190]	validation_0-auc:0.90935
# [191]	validation_0-auc:0.90935
# [192]	validation_0-auc:0.90935
# [193]	validation_0-auc:0.90935
# [194]	validation_0-auc:0.90935
# [195]	validation_0-auc:0.90935
# [196]	validation_0-auc:0.90935
# [197]	validation_0-auc:0.90935
# [198]	validation_0-auc:0.90935
# [199]	validation_0-auc:0.90935
# [200]	validation_0-auc:0.90935
# [201]	validation_0-auc:0.90935
# [202]	validation_0-auc:0.90928
# [203]	validation_0-auc:0.90928
# [204]	validation_0-auc:0.90928
# [205]	validation_0-auc:0.90928
# [206]	validation_0-auc:0.90928
# [207]	validation_0-auc:0.90928
# [208]	validation_0-auc:0.90928
# [209]	validation_0-auc:0.90928
# [210]	validation_0-auc:0.90928
# [211]	validation_0-auc:0.90928
# [212]	validation_0-auc:0.90928
# [213]	validation_0-auc:0.90928
# [214]	validation_0-auc:0.90928
# [215]	validation_0-auc:0.90949
# [216]	validation_0-auc:0.90949
# [217]	validation_0-auc:0.90949
# [218]	validation_0-auc:0.90949
# [219]	validation_0-auc:0.90949
# [220]	validation_0-auc:0.90949
# [221]	validation_0-auc:0.90949
# [222]	validation_0-auc:0.90949
# [223]	validation_0-auc:0.90949
# [224]	validation_0-auc:0.90941
# [225]	validation_0-auc:0.90941
# [226]	validation_0-auc:0.90941
# [227]	validation_0-auc:0.90943
# [228]	validation_0-auc:0.90943
# [229]	validation_0-auc:0.90943
# [230]	validation_0-auc:0.90943
# [231]	validation_0-auc:0.90943
# [232]	validation_0-auc:0.90943
# [233]	validation_0-auc:0.90943
# [234]	validation_0-auc:0.90943
# [235]	validation_0-auc:0.90943
# [236]	validation_0-auc:0.90943
# [237]	validation_0-auc:0.90943
# [238]	validation_0-auc:0.90943
# [239]	validation_0-auc:0.90943
# [240]	validation_0-auc:0.90943
# [241]	validation_0-auc:0.90943
# [242]	validation_0-auc:0.90943
# [243]	validation_0-auc:0.90943
# [244]	validation_0-auc:0.90943
# [245]	validation_0-auc:0.90943
# [246]	validation_0-auc:0.90943
# [247]	validation_0-auc:0.90943
# [248]	validation_0-auc:0.90943
# [249]	validation_0-auc:0.90943
# [250]	validation_0-auc:0.90943
# [251]	validation_0-auc:0.90937
# [252]	validation_0-auc:0.90937
# [253]	validation_0-auc:0.90937
# [254]	validation_0-auc:0.90937
# [255]	validation_0-auc:0.90937
# [256]	validation_0-auc:0.90937
# [257]	validation_0-auc:0.90937
# [258]	validation_0-auc:0.90947
# [259]	validation_0-auc:0.90947
# [260]	validation_0-auc:0.90947
# [261]	validation_0-auc:0.90947
# [262]	validation_0-auc:0.90947
# [263]	validation_0-auc:0.90947
# [264]	validation_0-auc:0.90947
# [265]	validation_0-auc:0.90947
# [266]	validation_0-auc:0.90947
# [267]	validation_0-auc:0.90947
# [268]	validation_0-auc:0.90947
# [269]	validation_0-auc:0.90947
# [270]	validation_0-auc:0.90947
# [271]	validation_0-auc:0.90947
# [272]	validation_0-auc:0.90947
# [273]	validation_0-auc:0.90947
# [274]	validation_0-auc:0.90947
# [275]	validation_0-auc:0.90947
# [276]	validation_0-auc:0.90947
# [277]	validation_0-auc:0.90947
# [278]	validation_0-auc:0.90947
# [279]	validation_0-auc:0.90947
# [280]	validation_0-auc:0.90947
# [281]	validation_0-auc:0.90947
# [282]	validation_0-auc:0.90947
# [283]	validation_0-auc:0.90947
# [284]	validation_0-auc:0.90947
# [285]	validation_0-auc:0.90948
# [286]	validation_0-auc:0.90948
# [287]	validation_0-auc:0.90948
# [288]	validation_0-auc:0.90948
# [289]	validation_0-auc:0.90949
# [290]	validation_0-auc:0.90949
# [291]	validation_0-auc:0.90949
# [292]	validation_0-auc:0.90952
# [293]	validation_0-auc:0.90952
# [294]	validation_0-auc:0.90952
# [295]	validation_0-auc:0.90952
# [296]	validation_0-auc:0.90952
# [297]	validation_0-auc:0.90952
# [298]	validation_0-auc:0.90952
# [299]	validation_0-auc:0.90952
# Accuracy: 0.8033352501437608
# ROC AUC: 0.9095223733710058

# %% [markdown]
# An accuracy of .8 is really good! The XGBoost is clearly better, at least compared to the MLP (~.55 after optimizations).
#
# I'll go with this model for my first submission. The goal is to see how well I'm doing so far, and if I should double down on this version or just keep trying different ways of modelling the problem.

# %% [markdown]
# ### Find the best thresold

# %%
# IMPROVEMENT: Use default threshold (0.5) to avoid overfitting to validation set
# Custom thresholds often don't generalize well to test data

best_t = 0.5
print(f"Using default threshold: {best_t:.2f}")
print(f"Validation accuracy at 0.5: {accuracy_score(y_test, y_proba > best_t):.4f}")
# Out:
# Using default threshold: 0.50
# Validation accuracy at 0.5: 0.8033

# %%
# Load the test data
df_submission_original = pd.read_csv('data/' + 'test.csv')
df_submission = pd.read_csv('data/' + 'test_processed.csv')

# Train multiple models and average their predictions
ensemble_probas = []
seeds = [67, 99, 111, 879, 2026]

for seed in seeds:
    print(f"Training model with seed {seed}...")
    ensemble_model = xgb.XGBClassifier(
        objective='binary:logistic',
        eval_metric='auc',
        n_estimators=grid.best_params_['n_estimators'],
        learning_rate=grid.best_params_['learning_rate'],
        max_depth=grid.best_params_['max_depth'],
        subsample=grid.best_params_['subsample'],
        colsample_bytree=grid.best_params_['colsample_bytree'],
        gamma=grid.best_params_['gamma'],
        min_child_weight=grid.best_params_['min_child_weight'],
        random_state=seed
    )
    
    ensemble_model.fit(X_train, y_train, verbose=False)
    proba = ensemble_model.predict_proba(df_submission)[:, 1]
    ensemble_probas.append(proba)

# Average predictions from all models
y_submission_proba = np.mean(ensemble_probas, axis=0)
y_submission_bool = (y_submission_proba > best_t)

submission_df = pd.DataFrame({
    'PassengerId': df_submission_original['PassengerId'],
    'Transported': y_submission_bool
})

submission_df.to_csv('data/submission.csv', index=False)
print(submission_df)
# Out:
# Training model with seed 67...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 25
#      11     ensemble_model = xgb.XGBClassifier(
#      12         objective='binary:logistic',
#      13         eval_metric='auc',
#    (...)
#      21         random_state=seed
#      22     )
#      24     ensemble_model.fit(X_train, y_train, verbose=False)
# ---> 25     proba = ensemble_model.predict_proba(df_submission)[:, 1]
#      26     ensemble_probas.append(proba)
#      28 # Average predictions from all models
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1797, in XGBClassifier.predict_proba(self, X, validate_features, base_margin, iteration_range)
#    1795     class_prob = softmax(raw_predt, axis=1)
#    1796     return class_prob
# -> 1797 class_probs = super().predict(
#    1798     X=X,
#    1799     validate_features=validate_features,
#    1800     base_margin=base_margin,
#    1801     iteration_range=iteration_range,
#    1802 )
#    1803 return _cls_predict_proba(self.n_classes_, class_probs, np.vstack)
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1327, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1325 if self._can_use_inplace_predict():
#    1326     try:
# -> 1327         predts = self.get_booster().inplace_predict(
#    1328             data=X,
#    1329             iteration_range=iteration_range,
#    1330             predict_type="margin" if output_margin else "value",
#    1331             missing=self.missing,
#    1332             base_margin=base_margin,
#    1333             validate_features=validate_features,
#    1334         )
#    1335         if _is_cupy_alike(predts):
#    1336             cp = import_cupy()
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/core.py:2667, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2665     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2666     if validate_features:
# -> 2667         self._validate_features(fns)
#    2668 if _is_list(data) or _is_tuple(data):
#    2669     data = np.array(data)
#
# File ~/projects/kaggle-spaceship-titanic/.venv/lib/python3.12/site-packages/xgboost/core.py:3243, in Booster._validate_features(self, feature_names)
#    3237 if my_missing:
#    3238     msg += (
#    3239         "\ntraining data did not have the following fields: "
#    3240         + ", ".join(str(s) for s in my_missing)
#    3241     )
# -> 3243 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Cabin_ID_1', 'Cabin_ID_2', 'Cabin_ID_3', 'GroupRank', 'GroupSize', 'IsAlone', 'RoomService_Cat', 'FoodCourt_Cat', 'ShoppingMall_Cat', 'Spa_Cat', 'VRDeck_Cat', 'EssentialSpendingCat', 'NonEssentialSpendingCat'] ['HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Cabin_ID_1', 'Cabin_ID_2', 'Cabin_ID_3', 'GroupRank', 'GroupSize', 'IsAlone', 'TotalSpending', 'HasSpending', 'CryoSpendingMismatch', 'RoomService_Cat', 'FoodCourt_Cat', 'ShoppingMall_Cat', 'Spa_Cat', 'VRDeck_Cat', 'AgeGroup', 'EssentialSpendingCat', 'NonEssentialSpendingCat']
# training data did not have the following fields: AgeGroup, TotalSpending, HasSpending, CryoSpendingMismatch
