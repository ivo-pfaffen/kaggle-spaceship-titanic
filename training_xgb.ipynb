# %% [markdown]
# ## Training (XGBoost edition)
# After loading and preprocessing the data, we can now train the model.
#
# ### First things first
# Importing libraries. Make sure you have them installed (check the instructions in the `README.md`)
#
# Then, let's find the best hyperparams using GridSearch

# %%
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

from sklearn.model_selection import GridSearchCV


# Load the processed data
df = pd.read_csv('data/' + 'train_processed.csv')

# Split features and labels
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8, 1],
    'colsample_bytree': [0.7, 0.8, 1]
}

grid = GridSearchCV(xgb.XGBClassifier(objective='binary:logistic', random_state=42),
                    param_grid,
                    scoring='roc_auc',
                    cv=3,
                    verbose=1,
                    n_jobs=-1)

grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# Best params: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500, 'subsample': 0.7}

# %% [markdown]
# ### On to training!
# Now that we have the best hyperparameters, let's train the classifier.

# %%
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=grid.best_params_['n_estimators'],
    learning_rate=grid.best_params_['learning_rate'],
    max_depth=grid.best_params_['max_depth'],
    subsample=grid.best_params_['subsample'],
    colsample_bytree=grid.best_params_['colsample_bytree'],
    random_state=42
)

model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print('Accuracy:', accuracy_score(y_test, y_pred))
print('ROC AUC:', roc_auc_score(y_test, y_proba))
# Out:
# [0]	validation_0-auc:0.84792
# [1]	validation_0-auc:0.84790
# [2]	validation_0-auc:0.86092
# [3]	validation_0-auc:0.86644
# [4]	validation_0-auc:0.87114
# [5]	validation_0-auc:0.87263
# [6]	validation_0-auc:0.87707
# [7]	validation_0-auc:0.87656
# [8]	validation_0-auc:0.87618
# [9]	validation_0-auc:0.87695
# [10]	validation_0-auc:0.87813
# [11]	validation_0-auc:0.87803
# [12]	validation_0-auc:0.87912
# [13]	validation_0-auc:0.87902
# [14]	validation_0-auc:0.87856
# [15]	validation_0-auc:0.87782
# [16]	validation_0-auc:0.87797
# [17]	validation_0-auc:0.87805
# [18]	validation_0-auc:0.87810
# [19]	validation_0-auc:0.87828
# [20]	validation_0-auc:0.87884
# [21]	validation_0-auc:0.87869
# [22]	validation_0-auc:0.87905
# [23]	validation_0-auc:0.87945
# [24]	validation_0-auc:0.88002
# [25]	validation_0-auc:0.88004
# [26]	validation_0-auc:0.87985
# [27]	validation_0-auc:0.87968
# [28]	validation_0-auc:0.87953
# [29]	validation_0-auc:0.87953
# [30]	validation_0-auc:0.87989
# [31]	validation_0-auc:0.88062
# [32]	validation_0-auc:0.88014
# [33]	validation_0-auc:0.87964
# [34]	validation_0-auc:0.87948
# [35]	validation_0-auc:0.87954
# [36]	validation_0-auc:0.87998
# [37]	validation_0-auc:0.88005
# [38]	validation_0-auc:0.88028
# [39]	validation_0-auc:0.88067
# [40]	validation_0-auc:0.88112
# [41]	validation_0-auc:0.88176
# [42]	validation_0-auc:0.88177
# [43]	validation_0-auc:0.88167
# [44]	validation_0-auc:0.88165
# [45]	validation_0-auc:0.88156
# [46]	validation_0-auc:0.88137
# [47]	validation_0-auc:0.88166
# [48]	validation_0-auc:0.88198
# [49]	validation_0-auc:0.88205
# [50]	validation_0-auc:0.88205
# [51]	validation_0-auc:0.88184
# [52]	validation_0-auc:0.88179
# [53]	validation_0-auc:0.88182
# [54]	validation_0-auc:0.88175
# [55]	validation_0-auc:0.88203
# [56]	validation_0-auc:0.88220
# [57]	validation_0-auc:0.88253
# [58]	validation_0-auc:0.88275
# [59]	validation_0-auc:0.88281
# [60]	validation_0-auc:0.88262
# [61]	validation_0-auc:0.88255
# [62]	validation_0-auc:0.88260
# [63]	validation_0-auc:0.88273
# [64]	validation_0-auc:0.88287
# [65]	validation_0-auc:0.88316
# [66]	validation_0-auc:0.88347
# [67]	validation_0-auc:0.88345
# [68]	validation_0-auc:0.88327
# [69]	validation_0-auc:0.88347
# [70]	validation_0-auc:0.88338
# [71]	validation_0-auc:0.88358
# [72]	validation_0-auc:0.88352
# [73]	validation_0-auc:0.88336
# [74]	validation_0-auc:0.88341
# [75]	validation_0-auc:0.88346
# [76]	validation_0-auc:0.88352
# [77]	validation_0-auc:0.88328
# [78]	validation_0-auc:0.88330
# [79]	validation_0-auc:0.88330
# [80]	validation_0-auc:0.88344
# [81]	validation_0-auc:0.88350
# [82]	validation_0-auc:0.88347
# [83]	validation_0-auc:0.88365
# [84]	validation_0-auc:0.88371
# [85]	validation_0-auc:0.88382
# [86]	validation_0-auc:0.88372
# [87]	validation_0-auc:0.88392
# [88]	validation_0-auc:0.88409
# [89]	validation_0-auc:0.88413
# [90]	validation_0-auc:0.88416
# [91]	validation_0-auc:0.88427
# [92]	validation_0-auc:0.88436
# [93]	validation_0-auc:0.88454
# [94]	validation_0-auc:0.88452
# [95]	validation_0-auc:0.88464
# [96]	validation_0-auc:0.88469
# [97]	validation_0-auc:0.88481
# [98]	validation_0-auc:0.88472
# [99]	validation_0-auc:0.88483
# [100]	validation_0-auc:0.88480
# [101]	validation_0-auc:0.88478
# [102]	validation_0-auc:0.88476
# [103]	validation_0-auc:0.88476
# [104]	validation_0-auc:0.88481
# [105]	validation_0-auc:0.88495
# [106]	validation_0-auc:0.88499
# [107]	validation_0-auc:0.88504
# [108]	validation_0-auc:0.88502
# [109]	validation_0-auc:0.88517
# [110]	validation_0-auc:0.88529
# [111]	validation_0-auc:0.88528
# [112]	validation_0-auc:0.88536
# [113]	validation_0-auc:0.88543
# [114]	validation_0-auc:0.88546
# [115]	validation_0-auc:0.88555
# [116]	validation_0-auc:0.88549
# [117]	validation_0-auc:0.88566
# [118]	validation_0-auc:0.88552
# [119]	validation_0-auc:0.88561
# [120]	validation_0-auc:0.88555
# [121]	validation_0-auc:0.88578
# [122]	validation_0-auc:0.88574
# [123]	validation_0-auc:0.88585
# [124]	validation_0-auc:0.88579
# [125]	validation_0-auc:0.88579
# [126]	validation_0-auc:0.88598
# [127]	validation_0-auc:0.88627
# [128]	validation_0-auc:0.88630
# [129]	validation_0-auc:0.88630
# [130]	validation_0-auc:0.88637
# [131]	validation_0-auc:0.88637
# [132]	validation_0-auc:0.88631
# [133]	validation_0-auc:0.88626
# [134]	validation_0-auc:0.88630
# [135]	validation_0-auc:0.88636
# [136]	validation_0-auc:0.88642
# [137]	validation_0-auc:0.88631
# [138]	validation_0-auc:0.88640
# [139]	validation_0-auc:0.88645
# [140]	validation_0-auc:0.88647
# [141]	validation_0-auc:0.88662
# [142]	validation_0-auc:0.88680
# [143]	validation_0-auc:0.88674
# [144]	validation_0-auc:0.88680
# [145]	validation_0-auc:0.88696
# [146]	validation_0-auc:0.88696
# [147]	validation_0-auc:0.88706
# [148]	validation_0-auc:0.88703
# [149]	validation_0-auc:0.88706
# [150]	validation_0-auc:0.88713
# [151]	validation_0-auc:0.88721
# [152]	validation_0-auc:0.88724
# [153]	validation_0-auc:0.88723
# [154]	validation_0-auc:0.88726
# [155]	validation_0-auc:0.88724
# [156]	validation_0-auc:0.88733
# [157]	validation_0-auc:0.88725
# [158]	validation_0-auc:0.88723
# [159]	validation_0-auc:0.88725
# [160]	validation_0-auc:0.88726
# [161]	validation_0-auc:0.88740
# [162]	validation_0-auc:0.88740
# [163]	validation_0-auc:0.88741
# [164]	validation_0-auc:0.88745
# [165]	validation_0-auc:0.88747
# [166]	validation_0-auc:0.88746
# [167]	validation_0-auc:0.88758
# [168]	validation_0-auc:0.88759
# [169]	validation_0-auc:0.88769
# [170]	validation_0-auc:0.88770
# [171]	validation_0-auc:0.88780
# [172]	validation_0-auc:0.88775
# [173]	validation_0-auc:0.88777
# [174]	validation_0-auc:0.88787
# [175]	validation_0-auc:0.88792
# [176]	validation_0-auc:0.88798
# [177]	validation_0-auc:0.88804
# [178]	validation_0-auc:0.88813
# [179]	validation_0-auc:0.88828
# [180]	validation_0-auc:0.88824
# [181]	validation_0-auc:0.88836
# [182]	validation_0-auc:0.88844
# [183]	validation_0-auc:0.88862
# [184]	validation_0-auc:0.88872
# [185]	validation_0-auc:0.88879
# [186]	validation_0-auc:0.88887
# [187]	validation_0-auc:0.88902
# [188]	validation_0-auc:0.88901
# [189]	validation_0-auc:0.88909
# [190]	validation_0-auc:0.88909
# [191]	validation_0-auc:0.88913
# [192]	validation_0-auc:0.88913
# [193]	validation_0-auc:0.88915
# [194]	validation_0-auc:0.88918
# [195]	validation_0-auc:0.88910
# [196]	validation_0-auc:0.88923
# [197]	validation_0-auc:0.88923
# [198]	validation_0-auc:0.88927
# [199]	validation_0-auc:0.88929
# [200]	validation_0-auc:0.88939
# [201]	validation_0-auc:0.88945
# [202]	validation_0-auc:0.88953
# [203]	validation_0-auc:0.88958
# [204]	validation_0-auc:0.88967
# [205]	validation_0-auc:0.88964
# [206]	validation_0-auc:0.88980
# [207]	validation_0-auc:0.88975
# [208]	validation_0-auc:0.88980
# [209]	validation_0-auc:0.88986
# [210]	validation_0-auc:0.88986
# [211]	validation_0-auc:0.88997
# [212]	validation_0-auc:0.88994
# [213]	validation_0-auc:0.88993
# [214]	validation_0-auc:0.89005
# [215]	validation_0-auc:0.89010
# [216]	validation_0-auc:0.89008
# [217]	validation_0-auc:0.89015
# [218]	validation_0-auc:0.89022
# [219]	validation_0-auc:0.89022
# [220]	validation_0-auc:0.89017
# [221]	validation_0-auc:0.89016
# [222]	validation_0-auc:0.89022
# [223]	validation_0-auc:0.89037
# [224]	validation_0-auc:0.89041
# [225]	validation_0-auc:0.89036
# [226]	validation_0-auc:0.89055
# [227]	validation_0-auc:0.89050
# [228]	validation_0-auc:0.89059
# [229]	validation_0-auc:0.89083
# [230]	validation_0-auc:0.89081
# [231]	validation_0-auc:0.89084
# [232]	validation_0-auc:0.89089
# [233]	validation_0-auc:0.89098
# [234]	validation_0-auc:0.89108
# [235]	validation_0-auc:0.89107
# [236]	validation_0-auc:0.89110
# [237]	validation_0-auc:0.89127
# [238]	validation_0-auc:0.89138
# [239]	validation_0-auc:0.89140
# [240]	validation_0-auc:0.89146
# [241]	validation_0-auc:0.89148
# [242]	validation_0-auc:0.89163
# [243]	validation_0-auc:0.89176
# [244]	validation_0-auc:0.89178
# [245]	validation_0-auc:0.89184
# [246]	validation_0-auc:0.89182
# [247]	validation_0-auc:0.89180
# [248]	validation_0-auc:0.89188
# [249]	validation_0-auc:0.89196
# [250]	validation_0-auc:0.89199
# [251]	validation_0-auc:0.89199
# [252]	validation_0-auc:0.89208
# [253]	validation_0-auc:0.89210
# [254]	validation_0-auc:0.89212
# [255]	validation_0-auc:0.89212
# [256]	validation_0-auc:0.89212
# [257]	validation_0-auc:0.89217
# [258]	validation_0-auc:0.89221
# [259]	validation_0-auc:0.89226
# [260]	validation_0-auc:0.89236
# [261]	validation_0-auc:0.89243
# [262]	validation_0-auc:0.89259
# [263]	validation_0-auc:0.89258
# [264]	validation_0-auc:0.89262
# [265]	validation_0-auc:0.89273
# [266]	validation_0-auc:0.89270
# [267]	validation_0-auc:0.89284
# [268]	validation_0-auc:0.89287
# [269]	validation_0-auc:0.89298
# [270]	validation_0-auc:0.89303
# [271]	validation_0-auc:0.89306
# [272]	validation_0-auc:0.89301
# [273]	validation_0-auc:0.89316
# [274]	validation_0-auc:0.89322
# [275]	validation_0-auc:0.89322
# [276]	validation_0-auc:0.89330
# [277]	validation_0-auc:0.89331
# [278]	validation_0-auc:0.89330
# [279]	validation_0-auc:0.89334
# [280]	validation_0-auc:0.89341
# [281]	validation_0-auc:0.89344
# [282]	validation_0-auc:0.89347
# [283]	validation_0-auc:0.89357
# [284]	validation_0-auc:0.89359
# [285]	validation_0-auc:0.89364
# [286]	validation_0-auc:0.89369
# [287]	validation_0-auc:0.89369
# [288]	validation_0-auc:0.89367
# [289]	validation_0-auc:0.89382
# [290]	validation_0-auc:0.89389
# [291]	validation_0-auc:0.89398
# [292]	validation_0-auc:0.89402
# [293]	validation_0-auc:0.89408
# [294]	validation_0-auc:0.89411
# [295]	validation_0-auc:0.89412
# [296]	validation_0-auc:0.89409
# [297]	validation_0-auc:0.89415
# [298]	validation_0-auc:0.89419
# [299]	validation_0-auc:0.89426
# [300]	validation_0-auc:0.89436
# [301]	validation_0-auc:0.89440
# [302]	validation_0-auc:0.89446
# [303]	validation_0-auc:0.89451
# [304]	validation_0-auc:0.89453
# [305]	validation_0-auc:0.89459
# [306]	validation_0-auc:0.89467
# [307]	validation_0-auc:0.89473
# [308]	validation_0-auc:0.89476
# [309]	validation_0-auc:0.89473
# [310]	validation_0-auc:0.89476
# [311]	validation_0-auc:0.89475
# [312]	validation_0-auc:0.89480
# [313]	validation_0-auc:0.89487
# [314]	validation_0-auc:0.89487
# [315]	validation_0-auc:0.89484
# [316]	validation_0-auc:0.89494
# [317]	validation_0-auc:0.89501
# [318]	validation_0-auc:0.89502
# [319]	validation_0-auc:0.89510
# [320]	validation_0-auc:0.89510
# [321]	validation_0-auc:0.89510
# [322]	validation_0-auc:0.89518
# [323]	validation_0-auc:0.89522
# [324]	validation_0-auc:0.89528
# [325]	validation_0-auc:0.89529
# [326]	validation_0-auc:0.89530
# [327]	validation_0-auc:0.89531
# [328]	validation_0-auc:0.89537
# [329]	validation_0-auc:0.89540
# [330]	validation_0-auc:0.89542
# [331]	validation_0-auc:0.89543
# [332]	validation_0-auc:0.89539
# [333]	validation_0-auc:0.89547
# [334]	validation_0-auc:0.89546
# [335]	validation_0-auc:0.89558
# [336]	validation_0-auc:0.89558
# [337]	validation_0-auc:0.89561
# [338]	validation_0-auc:0.89562
# [339]	validation_0-auc:0.89571
# [340]	validation_0-auc:0.89571
# [341]	validation_0-auc:0.89577
# [342]	validation_0-auc:0.89584
# [343]	validation_0-auc:0.89585
# [344]	validation_0-auc:0.89587
# [345]	validation_0-auc:0.89581
# [346]	validation_0-auc:0.89588
# [347]	validation_0-auc:0.89590
# [348]	validation_0-auc:0.89595
# [349]	validation_0-auc:0.89596
# [350]	validation_0-auc:0.89591
# [351]	validation_0-auc:0.89596
# [352]	validation_0-auc:0.89600
# [353]	validation_0-auc:0.89609
# [354]	validation_0-auc:0.89600
# [355]	validation_0-auc:0.89604
# [356]	validation_0-auc:0.89617
# [357]	validation_0-auc:0.89616
# [358]	validation_0-auc:0.89619
# [359]	validation_0-auc:0.89619
# [360]	validation_0-auc:0.89632
# [361]	validation_0-auc:0.89628
# [362]	validation_0-auc:0.89633
# [363]	validation_0-auc:0.89635
# [364]	validation_0-auc:0.89636
# [365]	validation_0-auc:0.89647
# [366]	validation_0-auc:0.89650
# [367]	validation_0-auc:0.89654
# [368]	validation_0-auc:0.89658
# [369]	validation_0-auc:0.89662
# [370]	validation_0-auc:0.89671
# [371]	validation_0-auc:0.89668
# [372]	validation_0-auc:0.89669
# [373]	validation_0-auc:0.89672
# [374]	validation_0-auc:0.89671
# [375]	validation_0-auc:0.89667
# [376]	validation_0-auc:0.89662
# [377]	validation_0-auc:0.89666
# [378]	validation_0-auc:0.89663
# [379]	validation_0-auc:0.89660
# [380]	validation_0-auc:0.89657
# [381]	validation_0-auc:0.89664
# [382]	validation_0-auc:0.89666
# [383]	validation_0-auc:0.89676
# [384]	validation_0-auc:0.89676
# [385]	validation_0-auc:0.89672
# [386]	validation_0-auc:0.89681
# [387]	validation_0-auc:0.89682
# [388]	validation_0-auc:0.89677
# [389]	validation_0-auc:0.89684
# [390]	validation_0-auc:0.89684
# [391]	validation_0-auc:0.89692
# [392]	validation_0-auc:0.89697
# [393]	validation_0-auc:0.89692
# [394]	validation_0-auc:0.89695
# [395]	validation_0-auc:0.89691
# [396]	validation_0-auc:0.89695
# [397]	validation_0-auc:0.89693
# [398]	validation_0-auc:0.89694
# [399]	validation_0-auc:0.89693
# [400]	validation_0-auc:0.89698
# [401]	validation_0-auc:0.89704
# [402]	validation_0-auc:0.89701
# [403]	validation_0-auc:0.89699
# [404]	validation_0-auc:0.89703
# [405]	validation_0-auc:0.89714
# [406]	validation_0-auc:0.89713
# [407]	validation_0-auc:0.89722
# [408]	validation_0-auc:0.89722
# [409]	validation_0-auc:0.89725
# [410]	validation_0-auc:0.89728
# [411]	validation_0-auc:0.89735
# [412]	validation_0-auc:0.89735
# [413]	validation_0-auc:0.89731
# [414]	validation_0-auc:0.89731
# [415]	validation_0-auc:0.89740
# [416]	validation_0-auc:0.89747
# [417]	validation_0-auc:0.89751
# [418]	validation_0-auc:0.89753
# [419]	validation_0-auc:0.89753
# [420]	validation_0-auc:0.89753
# [421]	validation_0-auc:0.89753
# [422]	validation_0-auc:0.89752
# [423]	validation_0-auc:0.89754
# [424]	validation_0-auc:0.89757
# [425]	validation_0-auc:0.89756
# [426]	validation_0-auc:0.89769
# [427]	validation_0-auc:0.89773
# [428]	validation_0-auc:0.89766
# [429]	validation_0-auc:0.89765
# [430]	validation_0-auc:0.89764
# [431]	validation_0-auc:0.89765
# [432]	validation_0-auc:0.89766
# [433]	validation_0-auc:0.89767
# [434]	validation_0-auc:0.89769
# [435]	validation_0-auc:0.89776
# [436]	validation_0-auc:0.89779
# [437]	validation_0-auc:0.89780
# [438]	validation_0-auc:0.89784
# [439]	validation_0-auc:0.89789
# [440]	validation_0-auc:0.89787
# [441]	validation_0-auc:0.89786
# [442]	validation_0-auc:0.89786
# [443]	validation_0-auc:0.89781
# [444]	validation_0-auc:0.89781
# [445]	validation_0-auc:0.89780
# [446]	validation_0-auc:0.89781
# [447]	validation_0-auc:0.89781
# [448]	validation_0-auc:0.89783
# [449]	validation_0-auc:0.89789
# [450]	validation_0-auc:0.89792
# [451]	validation_0-auc:0.89796
# [452]	validation_0-auc:0.89794
# [453]	validation_0-auc:0.89796
# [454]	validation_0-auc:0.89795
# [455]	validation_0-auc:0.89799
# [456]	validation_0-auc:0.89803
# [457]	validation_0-auc:0.89808
# [458]	validation_0-auc:0.89811
# [459]	validation_0-auc:0.89811
# [460]	validation_0-auc:0.89812
# [461]	validation_0-auc:0.89813
# [462]	validation_0-auc:0.89815
# [463]	validation_0-auc:0.89824
# [464]	validation_0-auc:0.89831
# [465]	validation_0-auc:0.89831
# [466]	validation_0-auc:0.89834
# [467]	validation_0-auc:0.89835
# [468]	validation_0-auc:0.89833
# [469]	validation_0-auc:0.89834
# [470]	validation_0-auc:0.89831
# [471]	validation_0-auc:0.89833
# [472]	validation_0-auc:0.89839
# [473]	validation_0-auc:0.89838
# [474]	validation_0-auc:0.89842
# [475]	validation_0-auc:0.89837
# [476]	validation_0-auc:0.89840
# [477]	validation_0-auc:0.89838
# [478]	validation_0-auc:0.89840
# [479]	validation_0-auc:0.89841
# [480]	validation_0-auc:0.89842
# [481]	validation_0-auc:0.89841
# [482]	validation_0-auc:0.89843
# [483]	validation_0-auc:0.89840
# [484]	validation_0-auc:0.89837
# [485]	validation_0-auc:0.89842
# [486]	validation_0-auc:0.89844
# [487]	validation_0-auc:0.89845
# [488]	validation_0-auc:0.89846
# [489]	validation_0-auc:0.89849
# [490]	validation_0-auc:0.89849
# [491]	validation_0-auc:0.89847
# [492]	validation_0-auc:0.89850
# [493]	validation_0-auc:0.89859
# [494]	validation_0-auc:0.89858
# [495]	validation_0-auc:0.89856
# [496]	validation_0-auc:0.89849
# [497]	validation_0-auc:0.89848
# [498]	validation_0-auc:0.89854
# [499]	validation_0-auc:0.89857
# Accuracy: 0.8021851638872916
# ROC AUC: 0.8985731254993465

# %% [markdown]
# An accuracy of .8 is really good! The XGBoost is clearly better, at least compared to the MLP (~.55 after optimizations).
#
# I'll go with this model for my first submission. The goal is to see how well I'm doing so far, and if I should double down on this version or just keep trying different ways of modelling the problem.

# %% [markdown]
# ### Find the best thresold

# %%
thresholds = np.linspace(0, 1, 100)
accuracies = [(t, accuracy_score(y_test, y_proba > t)) for t in thresholds]
best_t, best_acc = max(accuracies, key=lambda x: x[1])
print(f"Best threshold: {best_t:.2f} with accuracy: {best_acc:.4f}")
# Out:
# Best threshold: 0.60 with accuracy: 0.8051

# %%
# Load the test data
df_submission_original = pd.read_csv('data/' + 'test.csv')
df_submission = pd.read_csv('data/' + 'test_processed.csv')

y_submission_pred = model.predict(df_submission)
y_submission_proba = model.predict_proba(df_submission)[:, 1]
y_submission_bool = (y_submission_proba > best_t) 

submission_df = pd.DataFrame({
    'PassengerId': df_submission_original['PassengerId'],
    'Transported': y_submission_bool
})

submission_df.to_csv('data/submission.csv', index=False)
print(submission_df)
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01         True
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]
