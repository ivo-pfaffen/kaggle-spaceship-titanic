# %% [markdown]
# ## Training (XGBoost edition)
# After loading and preprocessing the data, we can now train the model.
#
# ### First things first
# Importing libraries. Make sure you have them installed (check the instructions in the `README.md`)
#
# Then, let's find the best hyperparams using GridSearch

# %%
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

from sklearn.model_selection import GridSearchCV

# Load the processed data
df = pd.read_csv('data/' + 'train_processed.csv')

# Split features and labels
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


param_grid = {
    'n_estimators': [300, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [1],
    'colsample_bytree': [0.8, 1],
    'min_child_weight':[1, 5, 10],      
    'gamma':           [0, 1, 5]        
}

grid = GridSearchCV(xgb.XGBClassifier(objective='binary:logistic', random_state=42),
                    param_grid,
                    scoring='roc_auc',
                    cv=3,
                    verbose=1,
                    n_jobs=-1)

grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 324 candidates, totalling 972 fits
# Best params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 500, 'subsample': 1}

# %% [markdown]
# ### On to training!
# Now that we have the best hyperparameters, let's train the classifier.

# %%
# defaults: learning_rate=0.1, n_estimators=100, max_depth=6
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=grid.best_params_['n_estimators'],
    learning_rate=grid.best_params_['learning_rate'],
    max_depth=grid.best_params_['max_depth'],
    subsample=grid.best_params_['subsample'],
    colsample_bytree=grid.best_params_['colsample_bytree'],
    gamma=grid.best_params_['gamma'],
    min_child_weight=grid.best_params_['min_child_weight'],
    random_state=67
)

model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print('Accuracy:', accuracy_score(y_test, y_pred))
print('ROC AUC:', roc_auc_score(y_test, y_proba))
# Out:
# [0]	validation_0-auc:0.86395
# [1]	validation_0-auc:0.87214
# [2]	validation_0-auc:0.87163
# [3]	validation_0-auc:0.87335
# [4]	validation_0-auc:0.87713
# [5]	validation_0-auc:0.87814
# [6]	validation_0-auc:0.87886
# [7]	validation_0-auc:0.87960
# [8]	validation_0-auc:0.87980
# [9]	validation_0-auc:0.87995
# [10]	validation_0-auc:0.87934
# [11]	validation_0-auc:0.88067
# [12]	validation_0-auc:0.88006
# [13]	validation_0-auc:0.88095
# [14]	validation_0-auc:0.88161
# [15]	validation_0-auc:0.88203
# [16]	validation_0-auc:0.88232
# [17]	validation_0-auc:0.88333
# [18]	validation_0-auc:0.88373
# [19]	validation_0-auc:0.88439
# [20]	validation_0-auc:0.88420
# [21]	validation_0-auc:0.88428
# [22]	validation_0-auc:0.88408
# [23]	validation_0-auc:0.88491
# [24]	validation_0-auc:0.88503
# [25]	validation_0-auc:0.88602
# [26]	validation_0-auc:0.88579
# [27]	validation_0-auc:0.88577
# [28]	validation_0-auc:0.88618
# [29]	validation_0-auc:0.88649
# [30]	validation_0-auc:0.88627
# [31]	validation_0-auc:0.88600
# [32]	validation_0-auc:0.88569
# [33]	validation_0-auc:0.88593
# [34]	validation_0-auc:0.88597
# [35]	validation_0-auc:0.88659
# [36]	validation_0-auc:0.88623
# [37]	validation_0-auc:0.88628
# [38]	validation_0-auc:0.88620
# [39]	validation_0-auc:0.88647
# [40]	validation_0-auc:0.88665
# [41]	validation_0-auc:0.88668
# [42]	validation_0-auc:0.88688
# [43]	validation_0-auc:0.88709
# [44]	validation_0-auc:0.88737
# [45]	validation_0-auc:0.88765
# [46]	validation_0-auc:0.88788
# [47]	validation_0-auc:0.88811
# [48]	validation_0-auc:0.88811
# [49]	validation_0-auc:0.88795
# [50]	validation_0-auc:0.88808
# [51]	validation_0-auc:0.88805
# [52]	validation_0-auc:0.88831
# [53]	validation_0-auc:0.88839
# [54]	validation_0-auc:0.88845
# [55]	validation_0-auc:0.88842
# [56]	validation_0-auc:0.88863
# [57]	validation_0-auc:0.88872
# [58]	validation_0-auc:0.88882
# [59]	validation_0-auc:0.88884
# [60]	validation_0-auc:0.88892
# [61]	validation_0-auc:0.88891
# [62]	validation_0-auc:0.88886
# [63]	validation_0-auc:0.88910
# [64]	validation_0-auc:0.88900
# [65]	validation_0-auc:0.88890
# [66]	validation_0-auc:0.88902
# [67]	validation_0-auc:0.88892
# [68]	validation_0-auc:0.88879
# [69]	validation_0-auc:0.88873
# [70]	validation_0-auc:0.88869
# [71]	validation_0-auc:0.88869
# [72]	validation_0-auc:0.88872
# [73]	validation_0-auc:0.88865
# [74]	validation_0-auc:0.88867
# [75]	validation_0-auc:0.88879
# [76]	validation_0-auc:0.88882
# [77]	validation_0-auc:0.88892
# [78]	validation_0-auc:0.88903
# [79]	validation_0-auc:0.88922
# [80]	validation_0-auc:0.88922
# [81]	validation_0-auc:0.88933
# [82]	validation_0-auc:0.88934
# [83]	validation_0-auc:0.88937
# [84]	validation_0-auc:0.88949
# [85]	validation_0-auc:0.88956
# [86]	validation_0-auc:0.88959
# [87]	validation_0-auc:0.88989
# [88]	validation_0-auc:0.88991
# [89]	validation_0-auc:0.88996
# [90]	validation_0-auc:0.88987
# [91]	validation_0-auc:0.88990
# [92]	validation_0-auc:0.88996
# [93]	validation_0-auc:0.89006
# [94]	validation_0-auc:0.89002
# [95]	validation_0-auc:0.89013
# [96]	validation_0-auc:0.89021
# [97]	validation_0-auc:0.89059
# [98]	validation_0-auc:0.89060
# [99]	validation_0-auc:0.89053
# [100]	validation_0-auc:0.89049
# [101]	validation_0-auc:0.89059
# [102]	validation_0-auc:0.89066
# [103]	validation_0-auc:0.89084
# [104]	validation_0-auc:0.89092
# [105]	validation_0-auc:0.89110
# [106]	validation_0-auc:0.89089
# [107]	validation_0-auc:0.89091
# [108]	validation_0-auc:0.89088
# [109]	validation_0-auc:0.89103
# [110]	validation_0-auc:0.89103
# [111]	validation_0-auc:0.89105
# [112]	validation_0-auc:0.89106
# [113]	validation_0-auc:0.89118
# [114]	validation_0-auc:0.89116
# [115]	validation_0-auc:0.89113
# [116]	validation_0-auc:0.89104
# [117]	validation_0-auc:0.89103
# [118]	validation_0-auc:0.89101
# [119]	validation_0-auc:0.89096
# [120]	validation_0-auc:0.89107
# [121]	validation_0-auc:0.89103
# [122]	validation_0-auc:0.89102
# [123]	validation_0-auc:0.89105
# [124]	validation_0-auc:0.89106
# [125]	validation_0-auc:0.89103
# [126]	validation_0-auc:0.89108
# [127]	validation_0-auc:0.89110
# [128]	validation_0-auc:0.89123
# [129]	validation_0-auc:0.89131
# [130]	validation_0-auc:0.89163
# [131]	validation_0-auc:0.89176
# [132]	validation_0-auc:0.89176
# [133]	validation_0-auc:0.89204
# [134]	validation_0-auc:0.89215
# [135]	validation_0-auc:0.89243
# [136]	validation_0-auc:0.89260
# [137]	validation_0-auc:0.89259
# [138]	validation_0-auc:0.89264
# [139]	validation_0-auc:0.89264
# [140]	validation_0-auc:0.89263
# [141]	validation_0-auc:0.89263
# [142]	validation_0-auc:0.89264
# [143]	validation_0-auc:0.89269
# [144]	validation_0-auc:0.89261
# [145]	validation_0-auc:0.89281
# [146]	validation_0-auc:0.89266
# [147]	validation_0-auc:0.89266
# [148]	validation_0-auc:0.89293
# [149]	validation_0-auc:0.89288
# [150]	validation_0-auc:0.89310
# [151]	validation_0-auc:0.89312
# [152]	validation_0-auc:0.89310
# [153]	validation_0-auc:0.89313
# [154]	validation_0-auc:0.89317
# [155]	validation_0-auc:0.89328
# [156]	validation_0-auc:0.89327
# [157]	validation_0-auc:0.89327
# [158]	validation_0-auc:0.89323
# [159]	validation_0-auc:0.89354
# [160]	validation_0-auc:0.89349
# [161]	validation_0-auc:0.89347
# [162]	validation_0-auc:0.89345
# [163]	validation_0-auc:0.89334
# [164]	validation_0-auc:0.89332
# [165]	validation_0-auc:0.89327
# [166]	validation_0-auc:0.89332
# [167]	validation_0-auc:0.89327
# [168]	validation_0-auc:0.89325
# [169]	validation_0-auc:0.89334
# [170]	validation_0-auc:0.89339
# [171]	validation_0-auc:0.89327
# [172]	validation_0-auc:0.89324
# [173]	validation_0-auc:0.89370
# [174]	validation_0-auc:0.89374
# [175]	validation_0-auc:0.89374
# [176]	validation_0-auc:0.89396
# [177]	validation_0-auc:0.89408
# [178]	validation_0-auc:0.89437
# [179]	validation_0-auc:0.89457
# [180]	validation_0-auc:0.89475
# [181]	validation_0-auc:0.89473
# [182]	validation_0-auc:0.89505
# [183]	validation_0-auc:0.89500
# [184]	validation_0-auc:0.89506
# [185]	validation_0-auc:0.89534
# [186]	validation_0-auc:0.89533
# [187]	validation_0-auc:0.89549
# [188]	validation_0-auc:0.89554
# [189]	validation_0-auc:0.89559
# [190]	validation_0-auc:0.89568
# [191]	validation_0-auc:0.89596
# [192]	validation_0-auc:0.89611
# [193]	validation_0-auc:0.89609
# [194]	validation_0-auc:0.89605
# [195]	validation_0-auc:0.89607
# [196]	validation_0-auc:0.89606
# [197]	validation_0-auc:0.89615
# [198]	validation_0-auc:0.89625
# [199]	validation_0-auc:0.89642
# [200]	validation_0-auc:0.89646
# [201]	validation_0-auc:0.89648
# [202]	validation_0-auc:0.89650
# [203]	validation_0-auc:0.89665
# [204]	validation_0-auc:0.89680
# [205]	validation_0-auc:0.89680
# [206]	validation_0-auc:0.89686
# [207]	validation_0-auc:0.89696
# [208]	validation_0-auc:0.89708
# [209]	validation_0-auc:0.89703
# [210]	validation_0-auc:0.89701
# [211]	validation_0-auc:0.89703
# [212]	validation_0-auc:0.89707
# [213]	validation_0-auc:0.89708
# [214]	validation_0-auc:0.89712
# [215]	validation_0-auc:0.89723
# [216]	validation_0-auc:0.89717
# [217]	validation_0-auc:0.89720
# [218]	validation_0-auc:0.89734
# [219]	validation_0-auc:0.89737
# [220]	validation_0-auc:0.89750
# [221]	validation_0-auc:0.89749
# [222]	validation_0-auc:0.89751
# [223]	validation_0-auc:0.89750
# [224]	validation_0-auc:0.89766
# [225]	validation_0-auc:0.89776
# [226]	validation_0-auc:0.89782
# [227]	validation_0-auc:0.89788
# [228]	validation_0-auc:0.89791
# [229]	validation_0-auc:0.89789
# [230]	validation_0-auc:0.89793
# [231]	validation_0-auc:0.89798
# [232]	validation_0-auc:0.89801
# [233]	validation_0-auc:0.89801
# [234]	validation_0-auc:0.89807
# [235]	validation_0-auc:0.89807
# [236]	validation_0-auc:0.89814
# [237]	validation_0-auc:0.89826
# [238]	validation_0-auc:0.89836
# [239]	validation_0-auc:0.89842
# [240]	validation_0-auc:0.89848
# [241]	validation_0-auc:0.89862
# [242]	validation_0-auc:0.89862
# [243]	validation_0-auc:0.89865
# [244]	validation_0-auc:0.89874
# [245]	validation_0-auc:0.89881
# [246]	validation_0-auc:0.89880
# [247]	validation_0-auc:0.89878
# [248]	validation_0-auc:0.89879
# [249]	validation_0-auc:0.89877
# [250]	validation_0-auc:0.89876
# [251]	validation_0-auc:0.89889
# [252]	validation_0-auc:0.89887
# [253]	validation_0-auc:0.89889
# [254]	validation_0-auc:0.89886
# [255]	validation_0-auc:0.89886
# [256]	validation_0-auc:0.89894
# [257]	validation_0-auc:0.89888
# [258]	validation_0-auc:0.89898
# [259]	validation_0-auc:0.89896
# [260]	validation_0-auc:0.89902
# [261]	validation_0-auc:0.89911
# [262]	validation_0-auc:0.89909
# [263]	validation_0-auc:0.89904
# [264]	validation_0-auc:0.89903
# [265]	validation_0-auc:0.89914
# [266]	validation_0-auc:0.89920
# [267]	validation_0-auc:0.89926
# [268]	validation_0-auc:0.89931
# [269]	validation_0-auc:0.89934
# [270]	validation_0-auc:0.89932
# [271]	validation_0-auc:0.89946
# [272]	validation_0-auc:0.89949
# [273]	validation_0-auc:0.89954
# [274]	validation_0-auc:0.89966
# [275]	validation_0-auc:0.89971
# [276]	validation_0-auc:0.89970
# [277]	validation_0-auc:0.89971
# [278]	validation_0-auc:0.89971
# [279]	validation_0-auc:0.89973
# [280]	validation_0-auc:0.89975
# [281]	validation_0-auc:0.89984
# [282]	validation_0-auc:0.89984
# [283]	validation_0-auc:0.89999
# [284]	validation_0-auc:0.90010
# [285]	validation_0-auc:0.90015
# [286]	validation_0-auc:0.90019
# [287]	validation_0-auc:0.90031
# [288]	validation_0-auc:0.90029
# [289]	validation_0-auc:0.90042
# [290]	validation_0-auc:0.90047
# [291]	validation_0-auc:0.90050
# [292]	validation_0-auc:0.90058
# [293]	validation_0-auc:0.90061
# [294]	validation_0-auc:0.90058
# [295]	validation_0-auc:0.90066
# [296]	validation_0-auc:0.90076
# [297]	validation_0-auc:0.90078
# [298]	validation_0-auc:0.90085
# [299]	validation_0-auc:0.90088
# [300]	validation_0-auc:0.90095
# [301]	validation_0-auc:0.90106
# [302]	validation_0-auc:0.90109
# [303]	validation_0-auc:0.90112
# [304]	validation_0-auc:0.90114
# [305]	validation_0-auc:0.90125
# [306]	validation_0-auc:0.90135
# [307]	validation_0-auc:0.90140
# [308]	validation_0-auc:0.90147
# [309]	validation_0-auc:0.90152
# [310]	validation_0-auc:0.90157
# [311]	validation_0-auc:0.90167
# [312]	validation_0-auc:0.90172
# [313]	validation_0-auc:0.90174
# [314]	validation_0-auc:0.90182
# [315]	validation_0-auc:0.90187
# [316]	validation_0-auc:0.90189
# [317]	validation_0-auc:0.90191
# [318]	validation_0-auc:0.90192
# [319]	validation_0-auc:0.90191
# [320]	validation_0-auc:0.90202
# [321]	validation_0-auc:0.90211
# [322]	validation_0-auc:0.90217
# [323]	validation_0-auc:0.90229
# [324]	validation_0-auc:0.90229
# [325]	validation_0-auc:0.90240
# [326]	validation_0-auc:0.90242
# [327]	validation_0-auc:0.90246
# [328]	validation_0-auc:0.90245
# [329]	validation_0-auc:0.90253
# [330]	validation_0-auc:0.90265
# [331]	validation_0-auc:0.90268
# [332]	validation_0-auc:0.90277
# [333]	validation_0-auc:0.90275
# [334]	validation_0-auc:0.90282
# [335]	validation_0-auc:0.90280
# [336]	validation_0-auc:0.90277
# [337]	validation_0-auc:0.90278
# [338]	validation_0-auc:0.90281
# [339]	validation_0-auc:0.90282
# [340]	validation_0-auc:0.90290
# [341]	validation_0-auc:0.90305
# [342]	validation_0-auc:0.90310
# [343]	validation_0-auc:0.90316
# [344]	validation_0-auc:0.90315
# [345]	validation_0-auc:0.90315
# [346]	validation_0-auc:0.90322
# [347]	validation_0-auc:0.90324
# [348]	validation_0-auc:0.90324
# [349]	validation_0-auc:0.90330
# [350]	validation_0-auc:0.90329
# [351]	validation_0-auc:0.90331
# [352]	validation_0-auc:0.90330
# [353]	validation_0-auc:0.90335
# [354]	validation_0-auc:0.90335
# [355]	validation_0-auc:0.90339
# [356]	validation_0-auc:0.90342
# [357]	validation_0-auc:0.90352
# [358]	validation_0-auc:0.90356
# [359]	validation_0-auc:0.90357
# [360]	validation_0-auc:0.90355
# [361]	validation_0-auc:0.90352
# [362]	validation_0-auc:0.90358
# [363]	validation_0-auc:0.90368
# [364]	validation_0-auc:0.90368
# [365]	validation_0-auc:0.90365
# [366]	validation_0-auc:0.90366
# [367]	validation_0-auc:0.90365
# [368]	validation_0-auc:0.90373
# [369]	validation_0-auc:0.90384
# [370]	validation_0-auc:0.90383
# [371]	validation_0-auc:0.90385
# [372]	validation_0-auc:0.90387
# [373]	validation_0-auc:0.90392
# [374]	validation_0-auc:0.90396
# [375]	validation_0-auc:0.90397
# [376]	validation_0-auc:0.90395
# [377]	validation_0-auc:0.90400
# [378]	validation_0-auc:0.90394
# [379]	validation_0-auc:0.90392
# [380]	validation_0-auc:0.90398
# [381]	validation_0-auc:0.90396
# [382]	validation_0-auc:0.90396
# [383]	validation_0-auc:0.90399
# [384]	validation_0-auc:0.90401
# [385]	validation_0-auc:0.90398
# [386]	validation_0-auc:0.90395
# [387]	validation_0-auc:0.90399
# [388]	validation_0-auc:0.90397
# [389]	validation_0-auc:0.90401
# [390]	validation_0-auc:0.90404
# [391]	validation_0-auc:0.90405
# [392]	validation_0-auc:0.90405
# [393]	validation_0-auc:0.90406
# [394]	validation_0-auc:0.90407
# [395]	validation_0-auc:0.90410
# [396]	validation_0-auc:0.90410
# [397]	validation_0-auc:0.90412
# [398]	validation_0-auc:0.90415
# [399]	validation_0-auc:0.90420
# [400]	validation_0-auc:0.90421
# [401]	validation_0-auc:0.90424
# [402]	validation_0-auc:0.90427
# [403]	validation_0-auc:0.90428
# [404]	validation_0-auc:0.90430
# [405]	validation_0-auc:0.90433
# [406]	validation_0-auc:0.90435
# [407]	validation_0-auc:0.90439
# [408]	validation_0-auc:0.90441
# [409]	validation_0-auc:0.90444
# [410]	validation_0-auc:0.90453
# [411]	validation_0-auc:0.90459
# [412]	validation_0-auc:0.90458
# [413]	validation_0-auc:0.90460
# [414]	validation_0-auc:0.90462
# [415]	validation_0-auc:0.90464
# [416]	validation_0-auc:0.90469
# [417]	validation_0-auc:0.90472
# [418]	validation_0-auc:0.90477
# [419]	validation_0-auc:0.90476
# [420]	validation_0-auc:0.90481
# [421]	validation_0-auc:0.90485
# [422]	validation_0-auc:0.90495
# [423]	validation_0-auc:0.90502
# [424]	validation_0-auc:0.90505
# [425]	validation_0-auc:0.90507
# [426]	validation_0-auc:0.90506
# [427]	validation_0-auc:0.90514
# [428]	validation_0-auc:0.90521
# [429]	validation_0-auc:0.90519
# [430]	validation_0-auc:0.90518
# [431]	validation_0-auc:0.90519
# [432]	validation_0-auc:0.90521
# [433]	validation_0-auc:0.90521
# [434]	validation_0-auc:0.90522
# [435]	validation_0-auc:0.90527
# [436]	validation_0-auc:0.90530
# [437]	validation_0-auc:0.90531
# [438]	validation_0-auc:0.90533
# [439]	validation_0-auc:0.90535
# [440]	validation_0-auc:0.90536
# [441]	validation_0-auc:0.90536
# [442]	validation_0-auc:0.90537
# [443]	validation_0-auc:0.90538
# [444]	validation_0-auc:0.90538
# [445]	validation_0-auc:0.90543
# [446]	validation_0-auc:0.90544
# [447]	validation_0-auc:0.90543
# [448]	validation_0-auc:0.90544
# [449]	validation_0-auc:0.90545
# [450]	validation_0-auc:0.90545
# [451]	validation_0-auc:0.90551
# [452]	validation_0-auc:0.90550
# [453]	validation_0-auc:0.90556
# [454]	validation_0-auc:0.90559
# [455]	validation_0-auc:0.90560
# [456]	validation_0-auc:0.90562
# [457]	validation_0-auc:0.90562
# [458]	validation_0-auc:0.90561
# [459]	validation_0-auc:0.90564
# [460]	validation_0-auc:0.90565
# [461]	validation_0-auc:0.90569
# [462]	validation_0-auc:0.90571
# [463]	validation_0-auc:0.90580
# [464]	validation_0-auc:0.90581
# [465]	validation_0-auc:0.90584
# [466]	validation_0-auc:0.90588
# [467]	validation_0-auc:0.90589
# [468]	validation_0-auc:0.90593
# [469]	validation_0-auc:0.90593
# [470]	validation_0-auc:0.90596
# [471]	validation_0-auc:0.90597
# [472]	validation_0-auc:0.90596
# [473]	validation_0-auc:0.90598
# [474]	validation_0-auc:0.90600
# [475]	validation_0-auc:0.90603
# [476]	validation_0-auc:0.90604
# [477]	validation_0-auc:0.90604
# [478]	validation_0-auc:0.90604
# [479]	validation_0-auc:0.90607
# [480]	validation_0-auc:0.90608
# [481]	validation_0-auc:0.90608
# [482]	validation_0-auc:0.90609
# [483]	validation_0-auc:0.90611
# [484]	validation_0-auc:0.90610
# [485]	validation_0-auc:0.90609
# [486]	validation_0-auc:0.90607
# [487]	validation_0-auc:0.90608
# [488]	validation_0-auc:0.90608
# [489]	validation_0-auc:0.90609
# [490]	validation_0-auc:0.90617
# [491]	validation_0-auc:0.90619
# [492]	validation_0-auc:0.90617
# [493]	validation_0-auc:0.90618
# [494]	validation_0-auc:0.90617
# [495]	validation_0-auc:0.90619
# [496]	validation_0-auc:0.90621
# [497]	validation_0-auc:0.90622
# [498]	validation_0-auc:0.90629
# [499]	validation_0-auc:0.90629
# Accuracy: 0.81196089706728
# ROC AUC: 0.9062948089123107

# %% [markdown]
# An accuracy of .8 is really good! The XGBoost is clearly better, at least compared to the MLP (~.55 after optimizations).
#
# I'll go with this model for my first submission. The goal is to see how well I'm doing so far, and if I should double down on this version or just keep trying different ways of modelling the problem.

# %% [markdown]
# ### Find the best thresold

# %%
# IMPROVEMENT: Use default threshold (0.5) to avoid overfitting to validation set
# Custom thresholds often don't generalize well to test data

best_t = 0.5
print(f"Using default threshold: {best_t:.2f}")
print(f"Validation accuracy at 0.5: {accuracy_score(y_test, y_proba > best_t):.4f}")
# Out:
# Using default threshold: 0.50
# Validation accuracy at 0.5: 0.8120

# %%
# Load the test data
df_submission_original = pd.read_csv('data/' + 'test.csv')
df_submission = pd.read_csv('data/' + 'test_processed.csv')

# Train multiple models and average their predictions
ensemble_probas = []
seeds = [67, 99, 111, 879, 2026]

for seed in seeds:
    print(f"Training model with seed {seed}...")
    ensemble_model = xgb.XGBClassifier(
        objective='binary:logistic',
        eval_metric='auc',
        n_estimators=grid.best_params_['n_estimators'],
        learning_rate=grid.best_params_['learning_rate'],
        max_depth=grid.best_params_['max_depth'],
        subsample=grid.best_params_['subsample'],
        colsample_bytree=grid.best_params_['colsample_bytree'],
        gamma=grid.best_params_['gamma'],
        min_child_weight=grid.best_params_['min_child_weight'],
        random_state=seed
    )
    
    ensemble_model.fit(X_train, y_train, verbose=False)
    proba = ensemble_model.predict_proba(df_submission)[:, 1]
    ensemble_probas.append(proba)

# Average predictions from all models
y_submission_proba = np.mean(ensemble_probas, axis=0)
y_submission_bool = (y_submission_proba > best_t)

submission_df = pd.DataFrame({
    'PassengerId': df_submission_original['PassengerId'],
    'Transported': y_submission_bool
})

submission_df.to_csv('data/submission.csv', index=False)
print(submission_df)
# Out:
# Training model with seed 67...
# Training model with seed 99...
# Training model with seed 111...
# Training model with seed 879...
# Training model with seed 2026...
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]
