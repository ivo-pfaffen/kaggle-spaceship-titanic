# %% [markdown]
# ## Training (XGBoost edition)
# After loading and preprocessing the data, we can now train the model.
#
# ### First things first
# Importing libraries. Make sure you have them installed (check the instructions in the `README.md`)
#
# Then, let's find the best hyperparams using GridSearch

# %%
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

from sklearn.model_selection import GridSearchCV


# Load the processed data
df = pd.read_csv('data/' + 'train_processed.csv')

# Split features and labels
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8, 1],
    'colsample_bytree': [0.7, 0.8, 1]
}

grid = GridSearchCV(xgb.XGBClassifier(objective='binary:logistic', random_state=42),
                    param_grid,
                    scoring='roc_auc',
                    cv=3,
                    verbose=1,
                    n_jobs=-1)

grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# Best params: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'subsample': 0.8}

# %% [markdown]
# ### On to training!
# Now that we have the best hyperparameters, let's train the classifier.

# %%
# defaults: learning_rate=0.1, n_estimators=100, max_depth=6
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    n_estimators=grid.best_params_['n_estimators'],
    learning_rate=grid.best_params_['learning_rate'],
    max_depth=grid.best_params_['max_depth'],
    subsample=grid.best_params_['subsample'],
    colsample_bytree=grid.best_params_['colsample_bytree'],
    random_state=42
)

model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print('Accuracy:', accuracy_score(y_test, y_pred))
print('ROC AUC:', roc_auc_score(y_test, y_proba))
# Out:
# [0]	validation_0-auc:0.83842
# [1]	validation_0-auc:0.85933
# [2]	validation_0-auc:0.85990
# [3]	validation_0-auc:0.86193
# [4]	validation_0-auc:0.86384
# [5]	validation_0-auc:0.86672
# [6]	validation_0-auc:0.86878
# [7]	validation_0-auc:0.86949
# [8]	validation_0-auc:0.86917
# [9]	validation_0-auc:0.86880
# [10]	validation_0-auc:0.86941
# [11]	validation_0-auc:0.86997
# [12]	validation_0-auc:0.86995
# [13]	validation_0-auc:0.87193
# [14]	validation_0-auc:0.87143
# [15]	validation_0-auc:0.87126
# [16]	validation_0-auc:0.87198
# [17]	validation_0-auc:0.87249
# [18]	validation_0-auc:0.87297
# [19]	validation_0-auc:0.87361
# [20]	validation_0-auc:0.87389
# [21]	validation_0-auc:0.87426
# [22]	validation_0-auc:0.87508
# [23]	validation_0-auc:0.87584
# [24]	validation_0-auc:0.87615
# [25]	validation_0-auc:0.87675
# [26]	validation_0-auc:0.87711
# [27]	validation_0-auc:0.87757
# [28]	validation_0-auc:0.87799
# [29]	validation_0-auc:0.87841
# [30]	validation_0-auc:0.87864
# [31]	validation_0-auc:0.87978
# [32]	validation_0-auc:0.87985
# [33]	validation_0-auc:0.88007
# [34]	validation_0-auc:0.88067
# [35]	validation_0-auc:0.88063
# [36]	validation_0-auc:0.88015
# [37]	validation_0-auc:0.88058
# [38]	validation_0-auc:0.88100
# [39]	validation_0-auc:0.88347
# [40]	validation_0-auc:0.88359
# [41]	validation_0-auc:0.88376
# [42]	validation_0-auc:0.88388
# [43]	validation_0-auc:0.88445
# [44]	validation_0-auc:0.88541
# [45]	validation_0-auc:0.88546
# [46]	validation_0-auc:0.88537
# [47]	validation_0-auc:0.88552
# [48]	validation_0-auc:0.88564
# [49]	validation_0-auc:0.88608
# [50]	validation_0-auc:0.88733
# [51]	validation_0-auc:0.88711
# [52]	validation_0-auc:0.88743
# [53]	validation_0-auc:0.88817
# [54]	validation_0-auc:0.88829
# [55]	validation_0-auc:0.88966
# [56]	validation_0-auc:0.88969
# [57]	validation_0-auc:0.88949
# [58]	validation_0-auc:0.88986
# [59]	validation_0-auc:0.88982
# [60]	validation_0-auc:0.88986
# [61]	validation_0-auc:0.88984
# [62]	validation_0-auc:0.89047
# [63]	validation_0-auc:0.89075
# [64]	validation_0-auc:0.89184
# [65]	validation_0-auc:0.89220
# [66]	validation_0-auc:0.89293
# [67]	validation_0-auc:0.89316
# [68]	validation_0-auc:0.89313
# [69]	validation_0-auc:0.89361
# [70]	validation_0-auc:0.89390
# [71]	validation_0-auc:0.89395
# [72]	validation_0-auc:0.89409
# [73]	validation_0-auc:0.89417
# [74]	validation_0-auc:0.89480
# [75]	validation_0-auc:0.89547
# [76]	validation_0-auc:0.89566
# [77]	validation_0-auc:0.89605
# [78]	validation_0-auc:0.89611
# [79]	validation_0-auc:0.89643
# [80]	validation_0-auc:0.89653
# [81]	validation_0-auc:0.89690
# [82]	validation_0-auc:0.89691
# [83]	validation_0-auc:0.89754
# [84]	validation_0-auc:0.89791
# [85]	validation_0-auc:0.89798
# [86]	validation_0-auc:0.89800
# [87]	validation_0-auc:0.89817
# [88]	validation_0-auc:0.89844
# [89]	validation_0-auc:0.89859
# [90]	validation_0-auc:0.89901
# [91]	validation_0-auc:0.89903
# [92]	validation_0-auc:0.89906
# [93]	validation_0-auc:0.89930
# [94]	validation_0-auc:0.89921
# [95]	validation_0-auc:0.89930
# [96]	validation_0-auc:0.89954
# [97]	validation_0-auc:0.89948
# [98]	validation_0-auc:0.89981
# [99]	validation_0-auc:0.90032
# [100]	validation_0-auc:0.90042
# [101]	validation_0-auc:0.90056
# [102]	validation_0-auc:0.90096
# [103]	validation_0-auc:0.90091
# [104]	validation_0-auc:0.90114
# [105]	validation_0-auc:0.90119
# [106]	validation_0-auc:0.90167
# [107]	validation_0-auc:0.90168
# [108]	validation_0-auc:0.90196
# [109]	validation_0-auc:0.90207
# [110]	validation_0-auc:0.90211
# [111]	validation_0-auc:0.90215
# [112]	validation_0-auc:0.90233
# [113]	validation_0-auc:0.90252
# [114]	validation_0-auc:0.90278
# [115]	validation_0-auc:0.90289
# [116]	validation_0-auc:0.90300
# [117]	validation_0-auc:0.90301
# [118]	validation_0-auc:0.90304
# [119]	validation_0-auc:0.90310
# [120]	validation_0-auc:0.90308
# [121]	validation_0-auc:0.90331
# [122]	validation_0-auc:0.90347
# [123]	validation_0-auc:0.90348
# [124]	validation_0-auc:0.90383
# [125]	validation_0-auc:0.90384
# [126]	validation_0-auc:0.90382
# [127]	validation_0-auc:0.90411
# [128]	validation_0-auc:0.90413
# [129]	validation_0-auc:0.90415
# [130]	validation_0-auc:0.90415
# [131]	validation_0-auc:0.90421
# [132]	validation_0-auc:0.90407
# [133]	validation_0-auc:0.90428
# [134]	validation_0-auc:0.90429
# [135]	validation_0-auc:0.90436
# [136]	validation_0-auc:0.90444
# [137]	validation_0-auc:0.90449
# [138]	validation_0-auc:0.90450
# [139]	validation_0-auc:0.90452
# [140]	validation_0-auc:0.90470
# [141]	validation_0-auc:0.90479
# [142]	validation_0-auc:0.90476
# [143]	validation_0-auc:0.90483
# [144]	validation_0-auc:0.90504
# [145]	validation_0-auc:0.90514
# [146]	validation_0-auc:0.90524
# [147]	validation_0-auc:0.90522
# [148]	validation_0-auc:0.90521
# [149]	validation_0-auc:0.90509
# [150]	validation_0-auc:0.90510
# [151]	validation_0-auc:0.90516
# [152]	validation_0-auc:0.90519
# [153]	validation_0-auc:0.90524
# [154]	validation_0-auc:0.90533
# [155]	validation_0-auc:0.90555
# [156]	validation_0-auc:0.90565
# [157]	validation_0-auc:0.90562
# [158]	validation_0-auc:0.90565
# [159]	validation_0-auc:0.90558
# [160]	validation_0-auc:0.90556
# [161]	validation_0-auc:0.90562
# [162]	validation_0-auc:0.90562
# [163]	validation_0-auc:0.90569
# [164]	validation_0-auc:0.90580
# [165]	validation_0-auc:0.90597
# [166]	validation_0-auc:0.90592
# [167]	validation_0-auc:0.90595
# [168]	validation_0-auc:0.90598
# [169]	validation_0-auc:0.90597
# [170]	validation_0-auc:0.90601
# [171]	validation_0-auc:0.90615
# [172]	validation_0-auc:0.90614
# [173]	validation_0-auc:0.90609
# [174]	validation_0-auc:0.90614
# [175]	validation_0-auc:0.90616
# [176]	validation_0-auc:0.90615
# [177]	validation_0-auc:0.90612
# [178]	validation_0-auc:0.90606
# [179]	validation_0-auc:0.90631
# [180]	validation_0-auc:0.90637
# [181]	validation_0-auc:0.90639
# [182]	validation_0-auc:0.90643
# [183]	validation_0-auc:0.90637
# [184]	validation_0-auc:0.90638
# [185]	validation_0-auc:0.90632
# [186]	validation_0-auc:0.90639
# [187]	validation_0-auc:0.90643
# [188]	validation_0-auc:0.90635
# [189]	validation_0-auc:0.90646
# [190]	validation_0-auc:0.90652
# [191]	validation_0-auc:0.90645
# [192]	validation_0-auc:0.90638
# [193]	validation_0-auc:0.90639
# [194]	validation_0-auc:0.90640
# [195]	validation_0-auc:0.90642
# [196]	validation_0-auc:0.90638
# [197]	validation_0-auc:0.90658
# [198]	validation_0-auc:0.90657
# [199]	validation_0-auc:0.90655
# [200]	validation_0-auc:0.90656
# [201]	validation_0-auc:0.90661
# [202]	validation_0-auc:0.90678
# [203]	validation_0-auc:0.90665
# [204]	validation_0-auc:0.90678
# [205]	validation_0-auc:0.90679
# [206]	validation_0-auc:0.90684
# [207]	validation_0-auc:0.90680
# [208]	validation_0-auc:0.90675
# [209]	validation_0-auc:0.90674
# [210]	validation_0-auc:0.90686
# [211]	validation_0-auc:0.90688
# [212]	validation_0-auc:0.90687
# [213]	validation_0-auc:0.90686
# [214]	validation_0-auc:0.90690
# [215]	validation_0-auc:0.90691
# [216]	validation_0-auc:0.90689
# [217]	validation_0-auc:0.90679
# [218]	validation_0-auc:0.90699
# [219]	validation_0-auc:0.90702
# [220]	validation_0-auc:0.90709
# [221]	validation_0-auc:0.90702
# [222]	validation_0-auc:0.90713
# [223]	validation_0-auc:0.90717
# [224]	validation_0-auc:0.90721
# [225]	validation_0-auc:0.90722
# [226]	validation_0-auc:0.90730
# [227]	validation_0-auc:0.90729
# [228]	validation_0-auc:0.90724
# [229]	validation_0-auc:0.90718
# [230]	validation_0-auc:0.90715
# [231]	validation_0-auc:0.90721
# [232]	validation_0-auc:0.90720
# [233]	validation_0-auc:0.90720
# [234]	validation_0-auc:0.90721
# [235]	validation_0-auc:0.90723
# [236]	validation_0-auc:0.90741
# [237]	validation_0-auc:0.90758
# [238]	validation_0-auc:0.90753
# [239]	validation_0-auc:0.90760
# [240]	validation_0-auc:0.90767
# [241]	validation_0-auc:0.90760
# [242]	validation_0-auc:0.90775
# [243]	validation_0-auc:0.90774
# [244]	validation_0-auc:0.90773
# [245]	validation_0-auc:0.90777
# [246]	validation_0-auc:0.90776
# [247]	validation_0-auc:0.90774
# [248]	validation_0-auc:0.90775
# [249]	validation_0-auc:0.90782
# [250]	validation_0-auc:0.90788
# [251]	validation_0-auc:0.90780
# [252]	validation_0-auc:0.90785
# [253]	validation_0-auc:0.90780
# [254]	validation_0-auc:0.90783
# [255]	validation_0-auc:0.90787
# [256]	validation_0-auc:0.90787
# [257]	validation_0-auc:0.90783
# [258]	validation_0-auc:0.90782
# [259]	validation_0-auc:0.90813
# [260]	validation_0-auc:0.90806
# [261]	validation_0-auc:0.90798
# [262]	validation_0-auc:0.90794
# [263]	validation_0-auc:0.90792
# [264]	validation_0-auc:0.90795
# [265]	validation_0-auc:0.90803
# [266]	validation_0-auc:0.90804
# [267]	validation_0-auc:0.90798
# [268]	validation_0-auc:0.90797
# [269]	validation_0-auc:0.90809
# [270]	validation_0-auc:0.90802
# [271]	validation_0-auc:0.90807
# [272]	validation_0-auc:0.90819
# [273]	validation_0-auc:0.90814
# [274]	validation_0-auc:0.90812
# [275]	validation_0-auc:0.90816
# [276]	validation_0-auc:0.90815
# [277]	validation_0-auc:0.90827
# [278]	validation_0-auc:0.90817
# [279]	validation_0-auc:0.90818
# [280]	validation_0-auc:0.90827
# [281]	validation_0-auc:0.90830
# [282]	validation_0-auc:0.90828
# [283]	validation_0-auc:0.90830
# [284]	validation_0-auc:0.90835
# [285]	validation_0-auc:0.90829
# [286]	validation_0-auc:0.90829
# [287]	validation_0-auc:0.90816
# [288]	validation_0-auc:0.90828
# [289]	validation_0-auc:0.90821
# [290]	validation_0-auc:0.90825
# [291]	validation_0-auc:0.90826
# [292]	validation_0-auc:0.90817
# [293]	validation_0-auc:0.90817
# [294]	validation_0-auc:0.90816
# [295]	validation_0-auc:0.90819
# [296]	validation_0-auc:0.90829
# [297]	validation_0-auc:0.90824
# [298]	validation_0-auc:0.90827
# [299]	validation_0-auc:0.90838
# Accuracy: 0.8096607245543416
# ROC AUC: 0.9083788367011116

# %% [markdown]
# An accuracy of .8 is really good! The XGBoost is clearly better, at least compared to the MLP (~.55 after optimizations).
#
# I'll go with this model for my first submission. The goal is to see how well I'm doing so far, and if I should double down on this version or just keep trying different ways of modelling the problem.

# %% [markdown]
# ### Find the best thresold

# %%
thresholds = np.linspace(0, 1, 100)
accuracies = [(t, accuracy_score(y_test, y_proba > t)) for t in thresholds]
best_t, best_acc = max(accuracies, key=lambda x: x[1])
print(f"Best threshold: {best_t:.2f} with accuracy: {best_acc:.4f}")
# Out:
# Best threshold: 0.54 with accuracy: 0.8131

# %%
# Load the test data
df_submission_original = pd.read_csv('data/' + 'test.csv')
df_submission = pd.read_csv('data/' + 'test_processed.csv')

y_submission_pred = model.predict(df_submission)
y_submission_proba = model.predict_proba(df_submission)[:, 1]
y_submission_bool = (y_submission_proba > best_t) 

submission_df = pd.DataFrame({
    'PassengerId': df_submission_original['PassengerId'],
    'Transported': y_submission_bool
})

submission_df.to_csv('data/submission.csv', index=False)
print(submission_df)
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01         True
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]
